# %%
import pandas as pd
import numpy as np

# %%
S6 = pd.read_csv("pathway_list_0601.csv")

# %%
S6.head()
# Out:
#                                        Umbrella  \
# 0  Development pathway of multiple tissue types
# 1  Development pathway of multiple tissue types
# 2  Development pathway of multiple tissue types
# 3  Development pathway of multiple tissue types
# 4  Development pathway of multiple tissue types
#
#                     Name of GO pathways
# 0                   GO_BONE_DEVELOPMENT
# 1  GO_CARDIAC_MUSCLE_TISSUE_DEVELOPMENT
# 2            GO_CHONDROCYTE_DEVELOPMENT
# 3                    GO_EAR_DEVELOPMENT
# 4              GO_FOREBRAIN_DEVELOPMENT

# %%
d_um = {}
for i in range(S6.shape[0]):
    li = S6.iloc[i,:]
    if li[0] in d_um:
        d_um[li[0]].append(li[1])
    else:
        d_um[li[0]] = [li[1]]

# %%
PATHWAYS = S6['Name of GO pathways'].values

# %%
len(PATHWAYS)
# Out:
# 79

# %%
tumors = ['COAD','KIRP', 'BRCA', 'LIHC', 'THCA', 'STAD', 'KIRC', 'HNSC', 'LUAD']
tumors.sort()

# %%
# df_large = pd.DataFrame(columns = df_now.columns)
# for t in tumors:
#     df_now = pd.read_excel("GSEA_early_late_0604/TCGA-" + t +".xlsx")
#     df_large = pd.concat([df_large,df_now])

# %%
S1 = pd.read_csv("new_results/S20.csv")
S1 = S1.drop("Unnamed: 0",1)

# %%
f = open("c5.all.v7.1.symbols.gmt")
raw = f.readlines()
f.close()
go_d = {}
for i in raw:
    name,li = i.split()[0],i.split()[2:]
    go_d[name] = li
f = open("c2.all.v7.1.symbols.gmt")
raw = f.readlines()
f.close()
c2_d = {}
for i in raw:
    name,li = i.split()[0],i.split()[2:]
    c2_d[name] = li

# %%
out_df = pd.DataFrame(index = PATHWAYS,columns=tumors)

# %%
df_111 = pd.read_csv("microindels-1.csv")

# %%
df_111.head()
# Out:
#      Project TumorStage  SampeNum  Symbol  MutationNum  GeneLength
# 0  TCGA-BRCA      Early       805     TTN          289      304813
# 1  TCGA-BRCA      Early       805  PIK3CA          264       91979
# 2  TCGA-BRCA      Early       805    TP53          238       25771
# 3  TCGA-BRCA      Early       805   MUC16          124      132498
# 4  TCGA-BRCA      Early       805   GATA3           85       29820

# %%
# import os
# for dirpath, dnames, fnames in os.walk("GSEA_early_late_0726/"):
#     fnames.sort()
#     for i,file in enumerate(fnames):
#         if len(file.split(".")) == 2:
#             stage_type,exd = file.split(".")           
#             if exd == "xlsx" and stage_type[:4] == 'TCGA':
#                 xl = pd.ExcelFile(dirpath + "//"+ file)
#                 tumor = stage_type.split("_")[0]
#                 tumor = tumor.split('-')[1]
#                 for p in PATHWAYS:
#                     out = []
#                     for sheet in xl.sheet_names: 
#                         df = xl.parse(sheet)
#                         m_s1 = list(S1["TCGA-" + tumor + "_" + sheet.lower()].values)
#                         d_g = df_111.loc[df_111['Project'] == "TCGA-" + tumor].loc[df_111['pval'] < 0.2].loc[df_111['pathway']==p]
#                         if len(d_g) == 0:
#                             continue
#                         d_g_p = d_g['leadingEdge'].values[0].split("|")
#                         d_g_p = [i.strip() for i in d_g_p]
#                         #print(d_g_p)
# #                         if p in go_d:
# #                             g_p = go_d[p]
# #                         else:
# #                             g_p = c2_d[p]
#                         out += d_g_p
                    
#                     out_df.loc[p,tumor] = len(set(out))

# %%
#out_df
# Out:
#                                                    BRCA COAD HNSC KIRC KIRP  \
# GO_BONE_DEVELOPMENT                                 NaN  NaN  NaN  NaN  NaN
# GO_CARDIAC_MUSCLE_TISSUE_DEVELOPMENT                NaN  NaN  NaN  NaN  NaN
# GO_CHONDROCYTE_DEVELOPMENT                          NaN  NaN  NaN  NaN  NaN
# GO_EAR_DEVELOPMENT                                  NaN  NaN  NaN  NaN  NaN
# GO_FOREBRAIN_DEVELOPMENT                            NaN  NaN  NaN  NaN  NaN
# ...                                                 ...  ...  ...  ...  ...
# GO_ESTABLISHMENT_OF_PROTEIN_LOCALIZATION_TO_ORG...  NaN  NaN  NaN  NaN  NaN
# GO_MAINTENANCE_OF_PROTEIN_LOCALIZATION_IN_ORGAN...  NaN  NaN  NaN  NaN  NaN
# GO_ORGANELLE_LOCALIZATION                           NaN  NaN  NaN  NaN  NaN
# GO_ORGANELLE_TRANSPORT_ALONG_MICROTUBULE            NaN  NaN  NaN  NaN  NaN
# GO_PROTEIN_LOCALIZATION_TO_ORGANELLE                NaN  NaN  NaN  NaN  NaN
#
# ...

# %%
# out_df.to_csv("number of mutations per pathway.csv")

# %%
df_up_down = pd.read_csv("GSEA_all_samples.csv")

# %%
df_c = df_up_down.loc[df_up_down['pathway'].isin(PATHWAYS)].loc[df_up_down['pval'] < 0.05]
df_c
# Out:
#          Project                                     pathway          pval  \
# 40     TCGA-BRCA                            GO_DNA_PACKAGING  4.374001e-12
# 142    TCGA-BRCA                     GO_SPINDLE_ORGANIZATION  4.875760e-07
# 145    TCGA-BRCA        GO_PROTEIN_LOCALIZATION_TO_ORGANELLE  5.947964e-07
# 169    TCGA-BRCA                   GO_ORGANELLE_LOCALIZATION  1.869662e-06
# 187    TCGA-BRCA  GO_ESTABLISHMENT_OF_ORGANELLE_LOCALIZATION  3.633221e-06
# ...          ...                                         ...           ...
# 73871  TCGA-THCA                     GO_GLIAL_CELL_MIGRATION  3.221083e-02
# 73881  TCGA-THCA               GO_GLIAL_CELL_DIFFERENTIATION  3.240741e-02
# 73968  TCGA-THCA       GO_INSULIN_RECEPTOR_SIGNALING_PATHWAY  3.666245e-02
# 74105  TCGA-THCA                      REACTOME_RET_SIGNALING  4.354588e-02
# 74130  TCGA-THCA               GO_MICROTUBULE_BASED_MOVEMENT  4.497172e-02
#
#                padj   log2err        ES       NES  size  \
# ...

# %%
tumor_up_down = []
for t in tumors:
    tumor_up_down.append(t + "_up")
    tumor_up_down.append(t + "_down")
tumor_up_down
# Out:
# ['BRCA_up',
#  'BRCA_down',
#  'COAD_up',
#  'COAD_down',
#  'HNSC_up',
#  'HNSC_down',
#  'KIRC_up',
#  'KIRC_down',
#  'KIRP_up',
#  'KIRP_down',
#  'LIHC_up',
#  'LIHC_down',
#  'LUAD_up',
#  'LUAD_down',
#  'STAD_up',
#  'STAD_down',
#  'THCA_up',
#  'THCA_down']

# %%
up_down_pval = []
for t in tumors:
    up_down_pval.append(t + "_up")
    up_down_pval.append(t + "_up_pval")
    up_down_pval.append(t + "_down")
    up_down_pval.append(t + "_down_pval")
up_down_pval
# Out:
# ['BRCA_up',
#  'BRCA_up_pval',
#  'BRCA_down',
#  'BRCA_down_pval',
#  'COAD_up',
#  'COAD_up_pval',
#  'COAD_down',
#  'COAD_down_pval',
#  'HNSC_up',
#  'HNSC_up_pval',
#  'HNSC_down',
#  'HNSC_down_pval',
#  'KIRC_up',
#  'KIRC_up_pval',
#  'KIRC_down',
#  'KIRC_down_pval',
#  'KIRP_up',
#  'KIRP_up_pval',
#  'KIRP_down',
#  'KIRP_down_pval',
#  'LIHC_up',
#  'LIHC_up_pval',
#  'LIHC_down',
#  'LIHC_down_pval',
#  'LUAD_up',
#  'LUAD_up_pval',
#  'LUAD_down',
#  'LUAD_down_pval',
#  'STAD_up',
#  'STAD_up_pval',
#  'STAD_down',
#  'STAD_down_pval',
#  'THCA_up',
#  'THCA_up_pval',
#  'THCA_down',
#  'THCA_down_pval']

# %%
df_c.loc[df_c['pathway'] == 'GO_CYTOSKELETON_ORGANIZATION']
# Out:
#          Project                       pathway          pval          padj  \
# 637    TCGA-BRCA  GO_CYTOSKELETON_ORGANIZATION  2.155995e-03  3.059752e-02
# 18785  TCGA-HNSC  GO_CYTOSKELETON_ORGANIZATION  2.278368e-03  3.118473e-02
# 45388  TCGA-LIHC  GO_CYTOSKELETON_ORGANIZATION  3.161936e-10  3.515604e-08
# 65795  TCGA-STAD  GO_CYTOSKELETON_ORGANIZATION  3.055229e-02  1.170181e-01
# 72722  TCGA-THCA  GO_CYTOSKELETON_ORGANIZATION  1.084040e-05  4.252158e-04
#
#         log2err        ES       NES  size  \
# 637    0.431708  0.431855  1.228503  1319
# 18785  0.431708 -0.380049 -1.214335  1323
# 45388  0.814036  0.587441  1.309812  1317
# 65795  0.282013  0.339842  1.164459  1323
# 72722  0.593325  0.497289  1.321538  1321
#
#                                              leadingEdge
# 637    KIF4A|PCLAF|TPX2|NUF2|SPC25|NUSAP1|CDK1|PLK1|K...
# 18785  FAM107A|OBSCN|KRT31|KAT2B|KRT84|CAPN3|SORBS1|T...
# 45388  SKA1|NUF2|KIFC1|BIRC5|KIF4A|NEK2|CDC20|KIF2C|A...
# ...

# %%
df_out_t4 = pd.DataFrame(index = PATHWAYS,columns =tumor_up_down )

# %%
for t in tumors:
    for p in PATHWAYS:
        up = df_c.loc[df_c['pathway'] == p].loc[df_c['Project'] == "TCGA-"+t].loc[df_c['NES'] > 0].shape[0]
        down = df_c.loc[df_c['pathway'] == p].loc[df_c['Project'] == "TCGA-"+t].loc[df_c['NES'] < 0].shape[0]
        df_out_t4.loc[p,t+"_up"] = up
        df_out_t4.loc[p,t+"_down"] = down

# %%
dev_paths = set()
for g in go_d:
    words = g.split("_")
    if "DEVELOPMENT" in words:
        dev_paths.add(g)

# %%
len(dev_paths)
# Out:
# 422

# %%
df_up = pd.read_csv("GSEA_all_samples_0601/GSEA_all_samples_up.csv")
df_down = pd.read_csv("GSEA_all_samples_0601/GSEA_all_samples_down.csv")
df_c_up = df_up.loc[df_up['pathway'].isin(PATHWAYS)].loc[df_up['pval'] < 0.01]
df_c_down = df_down.loc[df_down['pathway'].isin(PATHWAYS)].loc[df_down['pval'] < 0.01]

# %%
df_exp = pd.DataFrame(index = PATHWAYS,columns =tumor_up_down )

# %%
#df_exp1 = pd.DataFrame(index = PATHWAYS,columns = up_down_pval )

# %%
df_mu = pd.read_csv("GSEA_all_samples_0726/filtered_mutations_all_samples_GSEA_0726.csv")
df_mu = df_mu.loc[df_mu['pathway'].isin(PATHWAYS)].loc[df_mu['pval'] < 0.2]
df_mu.shape
# Out:
# (596, 9)

# %%
df_mu.head()
# Out:
#       Project                       pathway          pval          padj  \
# 3   TCGA-BRCA  GO_CYTOSKELETON_ORGANIZATION  1.131340e-12  2.552302e-09
# 9   TCGA-BRCA         GO_CELL_CELL_ADHESION  1.519243e-09  1.350864e-06
# 18  TCGA-BRCA         GO_NEURON_DEVELOPMENT  4.930628e-08  2.341789e-05
# 20  TCGA-BRCA     GO_NEURON_DIFFERENTIATION  9.490487e-08  4.078198e-05
# 68  TCGA-BRCA        GO_HEART_MORPHOGENESIS  4.458797e-06  5.831331e-04
#
#      log2err        ES       NES  size  \
# 3   0.910120  0.527294  1.545245   685
# 9   0.788187  0.549558  1.598776   432
# 18  0.719513  0.525459  1.534559   503
# 20  0.704976  0.493193  1.443435   646
# 68  0.610527  0.628474  1.785158   152
#
#                                           leadingEdge
# 3   TTN|DST|SYNE1|NEB|SPTA1|OBSCN|NCOR1|AKAP9|NF1|...
# 9   PIK3CA|CDH1|GATA3|HMCN1|SPTA1|FAT1|ERBB2|PIK3R...
# 18  PIK3CA|CDH1|GATA3|SPTA1|PTEN|LRP2|LRP1|HERC1|E...
# 20  PIK3CA|CDH1|GATA3|SPTA1|PTEN|LRP2|ASPM|LRP1|HE...
# ...

# %%
df_exp_mu = pd.DataFrame(index = PATHWAYS,columns =tumors )
for t in tumors:
    print(t)
    for p in PATHWAYS:
        mu = df_mu.loc[df_mu['pathway'] == p].loc[df_mu['Project'] == "TCGA-"+t].shape[0]
        df_exp_mu.loc[p,t] = mu
# Out:
# BRCA
# COAD
# HNSC
# KIRC
# KIRP
# LIHC
# LUAD
# STAD
# THCA

# %%
df_out_mu = pd.DataFrame(index = d_um.keys(),columns =tumors )
for key in d_um.keys():
    df_out_mu.loc[key] = df_exp_mu.loc[d_um[key]].sum()

# %%
df_out_mu.to_csv("table3_part2_0717.csv")

# %%
df_out_mu.gt(0).sum(axis=1)
# Out:
# Development pathway of multiple tissue types                      9
# Differentiation pathway of multiple cell types                    9
# Morphogenesis of multiple tissue types                            9
# Cell-cell adhesion                                                8
# Cell migration                                                    9
# DNA packaging                                                     9
# Spindle assembly and organization                                 7
# Cardiac muscle cell and neuronal action potential                 9
# Growth factor signaling pathway                                   9
# Autophagy of mitochondrion                                        9
# Endocytosis                                                       8
# Mitochondrion organization                                        2
# Protein localization to nucleus                                   9
# Key signaling pathways                                            8
# ...

# %%
df_yi = pd.read_excel("Table_2_all_samples(1).xlsx")

# %%
# for t in tumors:
#     print(t)
#     for p in df_yi['Pathway']:
#         up = df_yi.loc[df_yi['Pathway'] == p][t].values[0]
#         #print(p,up)
#         if np.isnan(up):
#             df_exp.loc[p,t+"_up"] = 0
#             df_exp.loc[p,t+"_down"] = 0
#             continue
#         if up > 0:
#             df_exp.loc[p,t+"_up"] = 1
#             df_exp.loc[p,t+"_down"] = 0
#         elif not np.isnan(up) and up < 0:
#             df_exp.loc[p,t+"_up"] = 0
#             df_exp.loc[p,t+"_down"] = 1

# %%
df_exp
# Out:
#                                                    BRCA_up BRCA_down COAD_up  \
# GO_BONE_DEVELOPMENT                                      1         0       1
# GO_CARDIAC_MUSCLE_TISSUE_DEVELOPMENT                     1         0       0
# GO_CHONDROCYTE_DEVELOPMENT                               1         0       1
# GO_EAR_DEVELOPMENT                                       1         0       1
# GO_FOREBRAIN_DEVELOPMENT                                 0         0       1
# ...                                                    ...       ...     ...
# GO_ESTABLISHMENT_OF_PROTEIN_LOCALIZATION_TO_ORG...       0         0       0
# GO_MAINTENANCE_OF_PROTEIN_LOCALIZATION_IN_ORGAN...       1         0       0
# GO_ORGANELLE_LOCALIZATION                                0         0       0
# GO_ORGANELLE_TRANSPORT_ALONG_MICROTUBULE                 1         0       0
# GO_PROTEIN_LOCALIZATION_TO_ORGANELLE                     0         0       0
#
# ...

# %%
df_out = pd.DataFrame(index = d_um.keys(),columns =tumor_up_down )
for key in d_um.keys():
    df_out.loc[key] = df_exp.loc[d_um[key]].sum()

# %%
int_up = [i+"_up" for i in tumors]

# %%
df_out[int_up].gt(0).sum(axis=1)
# Out:
# Development pathway of multiple tissue types                      9
# Differentiation pathway of multiple cell types                    9
# Morphogenesis of multiple tissue types                            8
# Cell-cell adhesion                                                1
# Cell migration                                                    7
# DNA packaging                                                     6
# Spindle assembly and organization                                 4
# Cardiac muscle cell and neuronal action potential                 6
# Growth factor signaling pathway                                   9
# Autophagy of mitochondrion                                        2
# Endocytosis                                                       1
# Mitochondrion organization                                        0
# Protein localization to nucleus                                   4
# Key signaling pathways                                            5
# ...

# %%
int_down = [i+"_down" for i in tumors]

# %%
df_out[int_down].gt(0).sum(axis=1)
#df_out[int_down]
# Out:
# Development pathway of multiple tissue types                      8
# Differentiation pathway of multiple cell types                    7
# Morphogenesis of multiple tissue types                            6
# Cell-cell adhesion                                                0
# Cell migration                                                    4
# DNA packaging                                                     0
# Spindle assembly and organization                                 0
# Cardiac muscle cell and neuronal action potential                 7
# Growth factor signaling pathway                                   8
# Autophagy of mitochondrion                                        4
# Endocytosis                                                       1
# Mitochondrion organization                                        0
# Protein localization to nucleus                                   0
# Key signaling pathways                                            2
# ...

# %%
df_exp_mu
# Out:
#                                                    BRCA COAD HNSC KIRC KIRP  \
# GO_BONE_DEVELOPMENT                                   1    1    1    1    1
# GO_CARDIAC_MUSCLE_TISSUE_DEVELOPMENT                  1    1    1    1    1
# GO_CHONDROCYTE_DEVELOPMENT                            1    1    1    1    0
# GO_EAR_DEVELOPMENT                                    1    1    1    1    1
# GO_FOREBRAIN_DEVELOPMENT                              1    1    1    1    1
# ...                                                 ...  ...  ...  ...  ...
# GO_ESTABLISHMENT_OF_PROTEIN_LOCALIZATION_TO_ORG...    1    0    1    1    1
# GO_MAINTENANCE_OF_PROTEIN_LOCALIZATION_IN_ORGAN...    1    1    1    0    1
# GO_ORGANELLE_LOCALIZATION                             1    1    1    1    1
# GO_ORGANELLE_TRANSPORT_ALONG_MICROTUBULE              1    1    1    1    1
# GO_PROTEIN_LOCALIZATION_TO_ORGANELLE                  1    1    1    1    1
#
# ...

# %%
df_out.to_csv("table3_0718.csv")

# %%
df_out_t4.to_csv("t4_draft1.csv")

# %%
df_up_down.loc[df_up_down['pathway'] == 'GO_CELL_CELL_ADHESION']
# Out:
#          Project                pathway          pval          padj   log2err  \
# 576    TCGA-BRCA  GO_CELL_CELL_ADHESION  1.380650e-03  2.168363e-02  0.455060
# 9386   TCGA-COAD  GO_CELL_CELL_ADHESION  3.798927e-06  1.059258e-04  0.627257
# 19406  TCGA-HNSC  GO_CELL_CELL_ADHESION  2.508540e-02  1.771620e-01  0.352488
# 27268  TCGA-KIRC  GO_CELL_CELL_ADHESION  2.244293e-09  2.419027e-07  0.774939
# 41843  TCGA-KIRP  GO_CELL_CELL_ADHESION  4.360465e-01  7.059170e-01  0.058969
# 54280  TCGA-LIHC  GO_CELL_CELL_ADHESION  9.990010e-01  1.000000e+00  0.001443
# 54449  TCGA-LUAD  GO_CELL_CELL_ADHESION  7.967726e-11  8.786847e-09  0.839089
# 63747  TCGA-STAD  GO_CELL_CELL_ADHESION  2.697756e-08  7.687756e-07  0.733762
# 72562  TCGA-THCA  GO_CELL_CELL_ADHESION  9.092741e-10  1.160413e-07  0.801216
#
#              ES       NES  size  \
# 576   -0.417938 -1.254515   838
# 9386  -0.417885 -1.378499   838
# 19406  0.386628  1.192491   839
# 27268  0.557403  1.461318   839
# ...

# %%
df_111.loc[df_111['Project'] =='TCGA-BRCA']
# Out:
#         Project                                     pathway          pval  \
# 0     TCGA-BRCA         GO_CELLULAR_COMPONENT_MORPHOGENESIS  1.600000e-19
# 1     TCGA-BRCA                       GO_ORGANELLE_ASSEMBLY  1.670000e-13
# 2     TCGA-BRCA                        GO_HEART_DEVELOPMENT  1.060000e-11
# 3     TCGA-BRCA                       GO_NEURON_DEVELOPMENT  1.680000e-11
# 4     TCGA-BRCA                GO_MICROTUBULE_BASED_PROCESS  1.890000e-11
# ...         ...                                         ...           ...
# 3593  TCGA-BRCA        REACTOME_OLFACTORY_SIGNALING_PATHWAY  9.950050e-01
# 3594  TCGA-BRCA  GO_SENSORY_PERCEPTION_OF_CHEMICAL_STIMULUS  9.970030e-01
# 3595  TCGA-BRCA       REACTOME_CD22_MEDIATED_BCR_REGULATION  9.980020e-01
# 3596  TCGA-BRCA        REACTOME_G_ALPHA_S_SIGNALLING_EVENTS  9.980020e-01
# 3597  TCGA-BRCA       GO_KILLING_OF_CELLS_OF_OTHER_ORGANISM  9.990010e-01
#
#               padj   log2err        ES       NES  size  \
# ...

# %%
df_S8 = pd.read_excel("Table_5_FC_early_late-0604.xlsx")

# %%
df_S8
# Out:
#                                               Pathway  BRCA_Early  BRCA_Late  \
# 0                                 GO_BONE_DEVELOPMENT   -0.901096  -0.903570
# 1                GO_CARDIAC_MUSCLE_TISSUE_DEVELOPMENT   -0.708702  -0.405809
# 2                          GO_CHONDROCYTE_DEVELOPMENT    0.638444  -1.059138
# 3                                  GO_EAR_DEVELOPMENT   -0.221818  -0.264285
# 4                            GO_FOREBRAIN_DEVELOPMENT         NaN        NaN
# ..                                                ...         ...        ...
# 73  GO_ESTABLISHMENT_OF_PROTEIN_LOCALIZATION_TO_OR...         NaN        NaN
# 74  GO_MAINTENANCE_OF_PROTEIN_LOCALIZATION_IN_ORGA...   -0.264911  -0.025649
# 75                          GO_ORGANELLE_LOCALIZATION         NaN        NaN
# 76           GO_ORGANELLE_TRANSPORT_ALONG_MICROTUBULE    0.129299   0.618097
# 77               GO_PROTEIN_LOCALIZATION_TO_ORGANELLE         NaN        NaN
#
# ...

# %%
df_S8.index = df_S8['Pathway']

# %%
df_out_s8 = pd.DataFrame(index = d_um.keys(),columns = df_S8.columns )
for key in d_um.keys():
    if key != "Mitochondrion organization":
        df_out_s8.loc[key] = df_S8.loc[d_um[key]].sum()

# %%
df_out_s8.to_csv("S8_stats.csv")

# %%
df_out_s8.drop('Pathway',1)
# Out:
#                                                    BRCA_Early BRCA_Late  \
# Development pathway of multiple tissue types         -5.68249  -10.6408
# Differentiation pathway of multiple cell types       -3.66562   -3.3877
# Morphogenesis of multiple tissue types               -5.90616  -6.83394
# Cell-cell adhesion                                          0         0
# Cell migration                                       -1.66301  -1.86732
# DNA packaging                                               0   0.69417
# Spindle assembly and organization                   -0.148193  0.820299
# Cardiac muscle cell and neuronal action potential     -5.1234    -5.771
# Growth factor signaling pathway                      -8.27348  -4.82382
# Autophagy of mitochondrion                           -0.74638  -1.02057
# Endocytosis                                                 0         0
# Mitochondrion organization                                NaN       NaN
# ...
